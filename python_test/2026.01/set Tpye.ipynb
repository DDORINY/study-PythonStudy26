# %%
# 집합 자료형 (set)
# 로또 주머니와 같이 중복을 허용하지 않고 순서가 없는
# 데이터들의 모임이다.
# 교집합, 합집합, 차집합 등의 연산을 쉽게 처리

s1 = set([1,2,3]) # set()에 값을 넣으면 된다.
print(s1)
# Out:
# {1, 2, 3}

# %%
s2 = set("hello")
print(s2)
#중복을 허용하지 않는다.
#순서가 없다(Unordered).
# Out:
# {'h', 'l', 'o', 'e'}

# %%
type(s2)
# Out:
# set

# %%
s3 ={1,2,3}
print(s3)
# Out:
# {1, 2, 3}

# %%
type(s3)
# Out:
# set

# %%
s4 ={'a','b','c'}
print(s4)
# Out:
# {'b', 'a', 'c'}

# %%
type(s4)
# Out:
# set

# %%
a=[1,2,3]
b=a
id(a)
# Out:
# 1962801737920

# %%
id(b)
# Out:
# 1962801737920

# %%
d=a[:]
a[1]=4
id(a)
print(b)
# Out:
# [1, 4, 3]

# %%
id(b)
# Out:
# 1962801737920

# %%
board_no=[]
no = len(board_no) + 1
board_no.append(no)
print(board_no)
# Out:
# [1]
